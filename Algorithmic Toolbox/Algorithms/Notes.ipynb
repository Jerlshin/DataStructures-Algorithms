# %% [markdown]
# ### Stress Test
#
# * Deliberate form of testing used to determine the stability, resilience, and reliability of a system, component, or entity by subjecting it to extreme, adverse conditions or significantly high load demands.
# * The primary goal is to identify the "breaking point" - the failure threshold - of the system.
